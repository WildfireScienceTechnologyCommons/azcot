# %%
from azcot_query import AzcotStore, plot_timeseries

# %%
# locations
anchorage = (61.216583, 149.899597)
canada = (46.3168, 79.4663)
greenland = (76.53, 68.75)

# %%
store = AzcotStore("https://scil-data.sdsc.edu/data/azcot/azcot.zarr")

# %%
df = store.timeseries(lat=anchorage[0], lon=anchorage[1])
plot_timeseries(df)

# %%
df = store.timeseries(lat=canada[0], lon=canada[1])
plot_timeseries(df)

# %%
df = store.timeseries(lat=greenland[0], lon=greenland[1])
plot_timeseries(df)
# Out:
# NOTE: SSRD is entirely NaN at (76.53, 68.75) -> nearest cell (76.5, 68.70000457763672). SSRD is masked to land in the source archive, so ocean points have no data. 2T/WS10 are not masked and will still return values here.
